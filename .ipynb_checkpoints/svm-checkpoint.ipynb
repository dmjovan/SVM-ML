# %% [markdown]
# # Učitavanje biblioteka za rad

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import random
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.utils import shuffle
import seaborn as sb
from cvxopt import matrix, solvers

solvers.options['show_progress'] = False

font = {'size'   : 13}

matplotlib.rc('font', **font)

# %% [markdown]
# # Implementacija potrebnih funkcija za učitavanje podataka

# %%
def get_classes_info(y: np.ndarray, show_text: bool=True) -> list:
    
    """
        Funkcija za izvlacenje klasa i prebrojavanja primera
        sa istom klasom
        
        params: 
            - y: vektor klasa
                               
        :return:
            - classes: lista klasa
            - classes_dict: recnik klasa sa njihovim brojem predstavnika
    """
    # dohvatanje svih vrednosti klasa
    classes = []
    for _class in y:
        if _class not in classes:
            classes.append(int(_class))
    classes.sort()
    
    assert classes == [-1, 1], 'Klase nisu odgovarajucih vrednosti!'
            
    # prebrojavanje predstavnika klasa
    classes_dict = dict.fromkeys(classes)
    for _class in classes:
        class_count = np.count_nonzero(y == _class)
        classes_dict[_class] = class_count
        
    # broj klasa
    k = len(classes_dict.keys())
        
    # ispis podataka o klasama u dataset-u
    if show_text:
        print('-------------------------------------------------------')
        print(f'Ukupan broj klasa kojima pripadaju ucitani primeri je: {k}\n')
        print('Ucitane klase i brojevi njhovih predstavnika/primera su: ')
        for _class in classes_dict.keys():
            pr = 'primera'
            if classes_dict[_class] % 10 == 1:
                pr = 'primer'
            print(f'\tKlasa {_class}: {classes_dict[_class]} {pr}')
        print('-------------------------------------------------------')
    
    return classes, classes_dict

# %%
def read_data(class_info: str='linear', separator_index: int=2) -> tuple:
    
    """
        Funkcija za ucitavanje podataka na osnovu kojih se
        kreira model.
        
        :params: 
            - class_info: informacija o tome kakve su klase ('linear' i 'nonlinear')
            - separator_index: broj kolone do koje se nalaze
                               ulazni podaci, odnosno od koje
                               pocinju izlazni podaci
                               
        :return:
            - X: matrica primera svih prediktora
            - y: vektor izlaza
    """
    
    if class_info == 'linear':
        path = 'svmData_ls.csv'
    elif class_info == 'nonlinear':
        path = 'svmData_nls.csv'
    
    data = pd.read_csv(path).to_numpy()
    
    # razdvajanje ulaznih i izlaznih promenljivih
    X, y = data[:,0:separator_index], data[:,separator_index]
    
    return X, y

# %%
def train_test_data_split(X: np.ndarray, y: np.ndarray, split_ratio: float=0.8) -> tuple:
    
    """
        Funkcija za mesanje klasa i splitovanje svih dostupnih podataka na 
        trening/obucavajuce i test podatke prema zadatom postotku (split_ratio).
        U funkciji se vodi racuna da balans izmedju klasa u dva nova skupa podataka
        bude isti kao i kod originalnih prosledjenih podataka.
        
        :params:
            - X: matrica primera svih prediktora
            - y: vektor klasa 
            - split_ratio: vrednost iz intervala [0,1] koja oznacava procenat
                           trening podataka
                           
        :return:
            - X_train: matrica primera svih prediktora za trening skup
            - y_train: vektor izlaza za trening skup
            - X_test: matrica primera svih prediktora za test skup
            - y_test: vektro izlaza za test skup
    """
    
    random.seed(1)
    
    # broj primera trening skupa
    m_train = 0
    
    classes, classes_dict = get_classes_info(y, False)
    
    train_indices = set()
    test_indices = set()
    
    # formiranje zasebnih splitova, kako bi svaka klasa imala split_ratio * 100% odbiraka u trening skupu
    for i in classes:
        m = classes_dict[i]
        
        class_train_set_size = int(m*split_ratio)
        m_train += class_train_set_size

        class_ind = np.where(y == i)[0].tolist()

        # odredjivanje indeksa za trening skup za jednu klasu
        class_train_set_ind = random.sample(class_ind, k=class_train_set_size)
        
        # dodavanje u globalni set indeksa za trening skup
        train_indices.update(list(class_train_set_ind))

        # odredjivanje indeksa za test skup za jednu klasu
        class_test_set_ind = set(class_ind) - set(class_train_set_ind)
        
        # dodavanje u globalni set indeksa za test skup
        test_indices.update(list(class_test_set_ind))
        
    train_indices = list(train_indices)
    test_indices = list(test_indices)
    
    # podela podataka na trening i test podatke
    X_train, y_train = X[train_indices], y[train_indices]
    X_test, y_test = X[test_indices], y[test_indices]
    
    # mesanje podataka
    X_train, y_train = shuffle(X_train, y_train, random_state=0)
    X_test, y_test = shuffle(X_test, y_test, random_state=0)
    
    return X_train, y_train, X_test, y_test

# %%
def get_fold_indeces(m: int, k: int=5) -> list:
    
    """
        Funkcija za dohvatanje listi pocetnih i krajnjih indeksa
        foldova na osnovu prosledjenog broja foldova - k i velicine celokupnog seta
        podataka - m.
        
        :params:
            - m: velicina skupa (broj primera jednog skupa) koji treba podeliti
                 u foldove
            - k: broj foldova
            
        :return:
            - fold_indeces: lista koja sadrzi liste u kojima su pocetna i krajnja tacka
                            svakog folda ponaosob
    """
    
    fold_size = int(m/k)
    
    fold_indeces = []
    
    for i in range(k):
        fold_indeces.append([i*fold_size, (i+1)*fold_size if i != k-1 else m])
        
    return fold_indeces

# %%
def get_fold(X: np.ndarray, y: np.ndarray, fold_index: list) -> tuple:
    
    """
        Funkcija za dohvatanje jednog folda podataka na osnovu proslednje
        liste koja sadrzi pocetni i krajnji indeks jednog folda.
        
        :params:
            - X: matrica primera svih prediktora iz koje treba izvuci jedan fold
            - y: vektor izlaza iz kojeg treba izvuci jedan fold
            - fold_index: lista koja sadrzi pocetni i krajnji indeks folda
                          koji treba izvuci
        
        :return:
            - (X_fold, y_fold): tuple sa izvucenim foldovima
    """
    
    X_fold = X[fold_index[0]:fold_index[1],:]
    
    y_fold = y[fold_index[0]:fold_index[1]]
    
    return (X_fold, y_fold)

# %%
def concat_folds(fold_1: tuple, fold_2: tuple=None) -> tuple:
    
    """
        Funkcija za spajanje dva odvojena folda podataka 
        koji u sebi sadrze i ulazne i izlazne podatke.
        
        :params:
            - fold_1: tuple koji sadzi X matricu i y vektor, respektivno,
                      koje treba spojiti sa fold_2
            - fold_2: tuple koji sadzi X matricu i y vektor, respektivno,
                      koje treba spojiti sa fold_1 
                      
                      **NOTE** fold_2 moze biti i None, u tom slucaju, funkcija vraca samo fold_1\
                      
        :return:
            - (X_concat, X_concat): tuple sa spojenim foldovima
    """
    
    try:
        X_1, y_1 = fold_1[0], fold_1[1]
        X_2, y_2 = fold_2[0], fold_2[1]

        # spajanje foldova ukoliko fold_2 postoji
        X_concat = np.concatenate((X_1, X_2), axis=0)
        Y_concat = np.concatenate((y_1, y_2), axis=0)
        
        return (X_concat, Y_concat)
    except:
        
        # vracanje samo prvog folda - fold_1, ukoliko fold_2 ne postoji
        return fold_1

# %%
def get_validation_and_train_folds(X: np.ndarray, y: np.ndarray, validation_fold_index: int, fold_indeces: list) -> tuple:
    
    """
        Funkcija za dohvatanje jednog folda podataka za validaciju i ostatak podataka
        za obucavanje.
        
        :params:
            - X: matrica primera svih prediktora
            - y: vektor izlaza
            - validation_fold_index: indeks iz elemeta liste fold_indeces za koji treba
                                     izvuci validacioni skup
            - fold_indeces: lista sa indeksima foldova
            
        :return:
            - validation_fold: fold podataka koji predstavlja validacioni skup
            - train_folds: spojeni svi preostali foldovi koji predstavljaju trening skup
    """
    
    # dohvatanja validacionog folda podataka
    validation_fold = get_fold(X, y, fold_indeces[validation_fold_index])
    
    # inicijalizacija trening foldova
    train_folds = None
    
    # dohvatanje trening foldova
    for i in range(len(fold_indeces)):
        if i != validation_fold_index:
            # dohvatanje pojedinacnog trening folda
            train_fold = get_fold(X, y, fold_indeces[i])
            # spajanje dohvacenog trening folda sa ostalim trening foldovima
            train_folds = concat_folds(train_fold, train_folds)
    
    return validation_fold, train_folds

# %%
def plot_data(X: np.ndarray, y: np.ndarray, title: str, w: list=None, b: float=None, support_vectors: np.ndarray=None) -> None:
    
    """
        Funkcija za iscrtavanje podataka (i separacionih prava dobijenih SVM-om).
        
        :params:
            - X: matrica primera svih prediktora
            - y: vektor klasa 
            - title: naslov plot-a
            - w: parametri SVM-a
            - b: parametar SVM-a
            - support_vectors: odredjeni potporni vektori
                           
        :return:
            - None
    """
    
    assert X.shape[1] == 2, 'Podatke nije moguce prikazati!' 
    
     # formula separacione prave za n=2
    sep_line = lambda x, b, w : -(b + w[0] * x) / w[1]
    
    fig = plt.figure(figsize=(12,10))
    plt.scatter(X[y==1, 0], X[y==1, 1], s = 50, c = 'blue', label = 'y = +1')
    plt.scatter(X[y==-1, 0], X[y==-1, 1], s = 50, c = 'red', label = 'y = -1')

    if w and b and support_vectors.any():
        # separacione prava
        xl, xr = plt.xlim()
        x = np.array([xl, xr])
        y_svm = sep_line(x, b, w)
        plt.plot(x, y_svm, '--', label='Separaciona prava')
        plt.scatter(support_vectors[:, 0], support_vectors[:, 1], 
                    s=100, marker='p', facecolors='none', edgecolor='darkgreen', linewidth=2, label='Potporni vektori')
        
    plt.xlabel('$X_1$')
    plt.ylabel('$X_2$')
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def plot_decision_boundary(clf, X, y, xmin, xmax, ymin, ymax, title, support_vectors):
    
    """
        Funkcija za iscrtavanje podataka (i separacionih oblasti dobijenih SVM-om).
        
        :params:
            - clf: klasifikator objekat
            - X: matrica primera svih prediktora
            - y: vektor klasa 
            - xmin: minimalna vrednost x-ose
            - xmax: maksimalna vrednost x-ose
            - ymin: minimalna vrednost y-ose
            - ymax: maksimalna vrednost y-ose
            - title: naslov plot-a
            - support_vectors: odredjeni potporni vektori
                           
        :return:
            - None
    """
    
    xx, yy = np.meshgrid(
      np.linspace(xmin, xmax, num=100, endpoint=True), 
      np.linspace(ymin, ymax, num=100, endpoint=True))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    fig, ax = plt.subplots(ncols=1, figsize=(12,10))
    cs = plt.contourf(xx, yy, Z, alpha=0.2)
    ax.set_title(title)
    plt.scatter(X[y==1, 0], X[y==1, 1], s = 50, c = 'blue', label = 'y = +1')
    plt.scatter(X[y==-1, 0], X[y==-1, 1], s = 50, c = 'red', label = 'y = -1')
    
    if support_vectors.any():
        plt.scatter(support_vectors[:, 0], support_vectors[:, 1], 
                    s=100, marker='p', facecolors='none', edgecolor='darkgreen', linewidth=2, label='Potporni vektori')
    
    ax.set_xlabel("$X_{1}$")
    ax.set_ylabel("$X_{2}$")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# # Implementacija funkcija za SVM

# %%
class SVM():
    
    """ Implementacije Support Vector Machine klasifikatora """
    
    def __init__(self, kernel_type: str='linear', reg: bool=False, C_reg: float=float('inf'), c: float=None, d: int=None):
        
        """ Konstruktor klase SVM """
        
        self.kernel_type = kernel_type
        self.reg = reg
        assert C_reg > 0, 'Nemoguca vrednost za konstantu C!'
        self.C_reg = C_reg
        self.c = c
        self.d = d
        self.alphas = None
        self.support_vectors = None
        self.w_opt = None
        self.b_opt = None
        
    def reset(self):
        
        """ Funckija za resetovanje modela """
        
        self.C_reg = float('inf')
        self.c = None
        self.d = None
        self.alphas = None
        self.support_vectors = None
        self.w_opt = None
        self.b_opt = None
        
    def set_hyper_params(self, C_reg: float=float('inf'), c: float=None, d: int=None):
        
        """ Funckija za postavljanje hiper-parametera """
    
        self.C_reg = C_reg
        self.c = c
        self.d = d
        
    def get_linear_kernel(self, X: np.ndarray, z: np.ndarray=None) -> np.ndarray:
        
        """ Funckija za dohvatanje linearnog kernela """
        
        m = X.shape[0]
        
        if z is None:
            result = X @ X.T
        else:
            result = X @ z.T
    
        return result
        
    def get_poly_kernel(self, X: np.ndarray, z: np.ndarray=None) -> np.ndarray:
        
        """ Funckija za dohvatanje polinomijalnog kernela """
        
        m = X.shape[0]
        
        if z is None:
            result = (X @ X.T + self.c)**self.d
        else:
            result = (X @ z.T + self.c)**self.d
    
        return result
    
    def solve_dual(self, X: np.ndarray, y: np.ndarray):
        
        """ Funckija za resavanje dualne forme Lagranzijana """
        
        m = X.shape[0]
        
        P = matrix((y.reshape((m,1)) @ y.reshape((1,m))) * getattr(self, 'get_' + self.kernel_type + '_kernel')(X), tc='d')
        q = matrix(-np.ones((m,1)), tc='d')        
        G = -np.identity(m)
        h = np.zeros((m,1))
        
        if self.reg and self.C_reg != float('inf'):
            G = np.concatenate((G, np.identity(m)), axis=0)
            h = np.concatenate((h, self.C_reg*np.ones((m,1))), axis=0)
            
        G = matrix(G, tc='d')
        h = matrix(h, tc='d')
        A = matrix(y.reshape((1,m)), tc='d')
        b = matrix([0], tc='d')
        
        sol = solvers.qp(P,q,G,h,A,b)

        self.alphas = np.array(sol['x']).reshape((-1,1))
    
    def calculate_support_vectors(self, X: np.ndarray, y: np.ndarray, t_low: float=1e-2) -> tuple:
        
        """ Funckija za dohvatanje potpornih vektora """
        
        alp = self.alphas.reshape(-1)
        indices = list(np.squeeze(np.argwhere(alp > t_low)))
        
        self.support_vectors = np.squeeze(X[indices])
        self.support_vectors_class = np.squeeze(y[indices])
        self.sv_indices = indices
                       
    def fit(self, X: np.ndarray, y: np.ndarray) -> tuple:
        
        """ Funckija za fitovanje modela - SVM """
        
        m = X.shape[0]
        
        self.solve_dual(X, y)
        
        self.w_opt = (self.alphas.reshape((m,1)) * y.reshape((m,1))).T @ X
        
        self.calculate_support_vectors(X, y) 
        
        random.seed(1)
        
        if self.reg: 
            alp = np.squeeze(self.alphas[self.sv_indices])
            indices_b = list(np.squeeze(np.argwhere(alp < (self.C_reg - 0.1))))

            sv = random.choice(np.squeeze(indices_b))
        else:
            sv = random.choice(np.squeeze(self.sv_indices))
        
        if self.kernel_type == 'linear':
            self.b_opt = y[sv] - self.w_opt.reshape((1,-1)) @ X[sv,:].reshape((-1,1)) 
        elif self.kernel_type == 'poly':
            self.b_opt = y[sv] - (self.alphas.T * y) @ self.get_poly_kernel(X, X[sv,:]) 
        
        assert self.w_opt.shape == (1, X.shape[1]), 'Parametar W nije dobro izracunat!'
        
        return list(np.squeeze(self.w_opt)),  float(self.b_opt), self.support_vectors
    
    def hinge_loss(self, X: np.ndarray, y: np.ndarray):
        
        """ Funckija za racunanje sarka / hinge gubitka """
        
        m = X.shape[0]
        hinge_params = np.zeros(m)
        for i in range(m):
            kernel = getattr(self, 'get_' + self.kernel_type + '_kernel')(self.support_vectors, X[i,:])
            hinge_params[i] = np.sum(self.alphas[self.sv_indices].flatten()*self.support_vectors_class.flatten()*kernel.flatten()) + self.b_opt
            
        hinge_params = 1 - y.flatten()*hinge_params
        hinge_params[hinge_params<0] = 0
        hinge_loss = np.sum(hinge_params)
        
        return hinge_loss
    
    def predict(self, X: np.ndarray) -> np.ndarray:
        
        """ Funckija za vrsenje predikcije modela  """
        
        m = X.shape[0]
        y_predict = np.zeros(m)
        
        for i in range(m):
            kernel = getattr(self, 'get_' + self.kernel_type + '_kernel')(self.support_vectors, X[i,:])
            y_predict[i] = np.sum(self.alphas[self.sv_indices].flatten()*self.support_vectors_class.flatten()*kernel.flatten()) + self.b_opt
            
        return np.sign(y_predict)

# %% [markdown]
# # Učitavanje podataka

# %%
X_lin, y_lin = read_data('linear')

print('#######################################################################################')
print('------------------- Ucitani su podaci za linearno separabilne klase -------------------')
print(f'Ukupan broj ucitanih primera je: {X_lin.shape[0]}')
print(f'Ukupan broj ucitanih prediktora (dim(X)) je: {X_lin.shape[1]}')

classes, _ = get_classes_info(y_lin)

X_nlin, y_nlin = read_data('nonlinear')

print('#######################################################################################')
print('------------------ Ucitani su podaci za nelinearno separabilne klase ------------------')
print(f'Ukupan broj ucitanih primera je: {X_nlin.shape[0]}')
print(f'Ukupan broj ucitanih prediktora (dim(X)) je: {X_nlin.shape[1]}')

classes, _ = get_classes_info(y_nlin)
# Out:
# #######################################################################################
# ------------------- Ucitani su podaci za linearno separabilne klase -------------------
# Ukupan broj ucitanih primera je: 49
# Ukupan broj ucitanih prediktora (dim(X)) je: 2
# -------------------------------------------------------
# Ukupan broj klasa kojima pripadaju ucitani primeri je: 2
#
# Ucitane klase i brojevi njhovih predstavnika/primera su:
# 	Klasa -1: 24 primera
# 	Klasa 1: 25 primera
# -------------------------------------------------------
# #######################################################################################
# ------------------ Ucitani su podaci za nelinearno separabilne klase ------------------
# Ukupan broj ucitanih primera je: 99
# Ukupan broj ucitanih prediktora (dim(X)) je: 2
# -------------------------------------------------------
# Ukupan broj klasa kojima pripadaju ucitani primeri je: 2
#
# Ucitane klase i brojevi njhovih predstavnika/primera su:
# ...

# %% [markdown]
# # Evaluacija implementiranog SVM-a nad podacima iz linearno separabilnih klasa

# %% [markdown]
# ## Linearni kernel, bez regularizacije

# %%
svm1 = SVM(kernel_type='linear', reg=False)
svm1_w, svm1_b, svm1_sv = svm1.fit(X_lin, y_lin)
plot_data(X_lin, y_lin, 'SVM sa linearnim kernelom, bez regularizacije', svm1_w, svm1_b, svm1_sv)

pred = svm1.predict(X_lin)
print(f'Broj validno klasifikovanih podataka: {sum(pred == y_lin.flatten())} / {y_lin.size}')
# Out:
# Broj validno klasifikovanih podataka: 49 / 49

# %% [markdown]
# Primetno je da SVM sa linearnim kernelom i bez regularizacije uspeva da prefektno resi ovaj problem, idealno razdvajacu klase na +1 i -1.

# %% [markdown]
# ## Linearni kernel sa "hinge" regularizacijom

# %% [markdown]
# ### Unakrsna validacija za pretragu hiper-parametra za Hinge regularizaciju

# %%
C_reg_linspace = np.linspace(1, 100, 100)
k = 5

svm2_cross = SVM(kernel_type='linear', reg=True)

fold_indeces = get_fold_indeces(m=X_lin.shape[0], k=k)

best_hinge = float('inf')

C_reg_best_1 = None

combinations = C_reg_linspace.size
itr = 0
for C_reg in C_reg_linspace:
            
    svm2_cross.set_hyper_params(C_reg)

    hinge = 0
    for i in range(k):
        val, _ = get_validation_and_train_folds(X_lin, y_lin, i, fold_indeces)

        X_val, y_val = val[0], val[1]

        _, _, _ = svm2_cross.fit(X_lin, y_lin)
        hinge += svm2_cross.hinge_loss(X_val, y_val)

    hinge /= k

    if hinge < best_hinge:
        best_hinge = hinge
        C_reg_best_1 = C_reg

    svm2_cross.reset()

    itr += 1

    print(f'Progres: {itr} / {combinations}', end='\r')
            
print('Pronadjeni optimalni hiper-parametri')
print(f'C_reg: {C_reg_best_1}')
print(f'Minimalna vrednost kriterijumske funkcije: {best_hinge}')
# Out:
# Pronadjeni optimalni hiper-parametri
# C_reg: 2.0
# Minimalna vrednost kriterijumske funkcije: 0.37765027988473393

# %%
svm2 = SVM(kernel_type='linear', reg=True, C_reg=C_reg_best_1)
svm2_w, svm2_b, svm2_sv = svm2.fit(X_lin, y_lin)
plot_data(X_lin, y_lin, f'SVM sa linearnim kernelom i regularizacijom (C = {C_reg_best_1})', svm2_w, svm2_b, svm2_sv)

pred = svm2.predict(X_lin)
print(f'Broj validno klasifikovanih podataka: {sum(pred == y_lin.flatten())} / {y_lin.size}')
# Out:
# Broj validno klasifikovanih podataka: 48 / 49

# %% [markdown]
# Za dobijene parametre kroz unakrsnu validaciju, gde zapravo ceo skup predstavlja trening skup, dobili smo klasifikaciju koja je za nijansu relaksirana, posto smo problematicnom odbirku dozvolili da predje u drugu klasu, a uspeli smo da maksimizujemo geometrijsku marginu sa regularizacijom modela.

# %% [markdown]
# ## Polinomijalni kernel sa "hinge" regularizacijom

# %% [markdown]
# ### Unakrsna validacija za pretragu hiper-parametera - slobodan clan c, stepen d i parametra Hinge regularizacije

# %%
C_reg_linspace = np.linspace(1, 100, 100)
c_linspace = np.linspace(1, 5, 5)
d_linspace = np.linspace(1, 5, 5)
k = 5

svm3_cross = SVM(kernel_type='poly', reg=True)

fold_indeces = get_fold_indeces(m=X_nlin.shape[0], k=k)

best_hinge = float('inf')

C_reg_best_2 = None
c_best = None
d_best = None

combinations = C_reg_linspace.size * c_linspace.size * d_linspace.size
itr = 0
for C_reg in C_reg_linspace:
    for c in c_linspace:
        for d in d_linspace:
            
            svm3_cross.set_hyper_params(C_reg, c, d)

            hinge = 0
            for i in range(k):
                val, _ = get_validation_and_train_folds(X_nlin, y_nlin, i, fold_indeces)

                X_val, y_val = val[0], val[1]
            
                _, _, _ = svm3_cross.fit(X_nlin, y_nlin)
                hinge += svm3_cross.hinge_loss(X_val, y_val)
                
            hinge /= k
            
            if hinge < best_hinge:
                best_hinge = hinge
                C_reg_best_2 = C_reg
                c_best = c
                d_best = d
            
            svm3_cross.reset()
            
            itr += 1
            
            print(f'Progres: {itr} / {combinations}', end='\r')
            
print('Pronadjeni optimalni hiper-parametri')
print(f'd: {d_best}')
print(f'c: {c_best}')
print(f'C_reg: {C_reg_best_2}')
print(f'Minimalna vrednost kriterijumske funkcije: {best_hinge}')
# Out:
# Pronadjeni optimalni hiper-parametri
# d: 5.0
# c: 1.0
# C_reg: 25.0
# Minimalna vrednost kriterijumske funkcije: 0.07617211979038388

# %%
svm3 = SVM(kernel_type='poly', reg=True, C_reg=C_reg_best_2, c=c_best, d=d_best)

svm3_w, svm3_b, svm3_sv = svm3.fit(X_nlin, y_nlin)
plot_decision_boundary(svm3, X_nlin, y_nlin, 0, 2, 0, 2, f'SVM sa polinomijalnim kernelom (c = {c_best},  d = {d_best}) i regularizacijom (C = {C_reg_best_2})', svm3_sv)

pred = svm3.predict(X_nlin)
print(f'Broj validno klasifikovanih podataka: {sum(pred == y_nlin.flatten())} / {y_nlin.size}')
# Out:
# Broj validno klasifikovanih podataka: 99 / 99

# %% [markdown]
# Sa parametrima dobijenim unakrsnom validacijom, dobili smo model koji je gotovo nepogresiv. Iako je sa slike primetno da je moguce sa polinomijalnim kernelom, gde je stepen jednak 3, jer imamo 2 prevojne tacke, unakrsnom validacijom je dobijeno da za nijansu podignemo stepen. Pored toga, opet je upotrebljen ceo skup podataka, kako se ne bi vodilo racuna o raspodeli klasa u trening skupu, a validacija je bila nasumicna. Primetan je 'overfit' posto dobijamo maltene odlicno razdvojene klase, sto bi se moglo ragulisati sa adekvatnom podelom podataka i naknadnom unakrsnom validacijom.
